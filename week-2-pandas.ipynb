# %%
t = (1,2,3,4)

t[1:3]
# Out:
# (2, 3)

# %%
import pandas as pd

dictionary = {"name":["ismail","cihan","berat","yasin","tayfun"],
             "age":[17,25,33,41,None],
             "note":[975,348,4432,254,None]}

dataframe1 = pd.DataFrame(dictionary) 
print(dataframe1)
# Out:
#      name   age    note
# 0  ismail  17.0   975.0
# 1   cihan  25.0   348.0
# 2   berat  33.0  4432.0
# 3   yasin  41.0   254.0
# 4  tayfun   NaN     NaN

# %%
head = dataframe1.head() 
print(head)
# Out:
#      name   age    note
# 0  ismail  17.0   975.0
# 1   cihan  25.0   348.0
# 2   berat  33.0  4432.0
# 3   yasin  41.0   254.0
# 4  tayfun   NaN     NaN

# %%
tail = dataframe1.tail()
print(tail)
# Out:
#      name   age    note
# 0  ismail  17.0   975.0
# 1   cihan  25.0   348.0
# 2   berat  33.0  4432.0
# 3   yasin  41.0   254.0
# 4  tayfun   NaN     NaN

# %%
print(dataframe1.columns)
# Out:
# Index(['name', 'age', 'note'], dtype='object')

# %%
print(dataframe1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   age     4 non-null      float64
#  2   note    4 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 248.0+ bytes
# None

# %%
print(dataframe1.dtypes)
# Out:
# name     object
# age     float64
# note    float64
# dtype: object

# %%
print(dataframe1.describe())
# Out:
#              age         note
# count   4.000000     4.000000
# mean   29.000000  1502.250000
# std    10.327956  1979.212701
# min    17.000000   254.000000
# 25%    23.000000   324.500000
# 50%    29.000000   661.500000
# 75%    35.000000  1839.250000
# max    41.000000  4432.000000

# %%
print(dataframe1["name"]) 
print(dataframe1.loc[:, "age"])                      
dataframe1["yeni_future"] = [1,2,3,4,5]
print(dataframe1.loc[:2,"age"]) 
print(dataframe1.loc[:2, "name":"note"])                 
print(dataframe1.loc[::-1])
# Out:
# 0    ismail
# 1     cihan
# 2     berat
# 3     yasin
# 4    tayfun
# Name: name, dtype: object
# 0    17.0
# 1    25.0
# 2    33.0
# 3    41.0
# 4     NaN
# Name: age, dtype: float64
# 0    17.0
# 1    25.0
# 2    33.0
# Name: age, dtype: float64
#      name   age    note
# 0  ismail  17.0   975.0
# 1   cihan  25.0   348.0
# 2   berat  33.0  4432.0
#      name   age    note  yeni_future
# 4  tayfun   NaN     NaN            5
# 3   yasin  41.0   254.0            4
# 2   berat  33.0  4432.0            3
# 1   cihan  25.0   348.0            2
# 0  ismail  17.0   975.0            1

# %%
print(dataframe1.yeni_future)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: yeni_future, dtype: int64

# %%
print(dataframe1.loc[:, "age"])
# Out:
# 0    17.0
# 1    25.0
# 2    33.0
# 3    41.0
# 4     NaN
# Name: age, dtype: float64

# %%
print(dataframe1.loc[:2, "age"])
# Out:
# 0    17.0
# 1    25.0
# 2    33.0
# Name: age, dtype: float64

# %%
print(dataframe1.loc[:1, "name":"note"])
# Out:
#      name   age   note
# 0  ismail  17.0  975.0
# 1   cihan  25.0  348.0

# %%
print(dataframe1.loc[:4, ["name","note"]])
# Out:
#      name    note
# 0  ismail   975.0
# 1   cihan   348.0
# 2   berat  4432.0
# 3   yasin   254.0
# 4  tayfun     NaN

# %%
print(dataframe1.loc[::-1])
# Out:
#      name   age    note  yeni_future
# 4  tayfun   NaN     NaN            5
# 3   yasin  41.0   254.0            4
# 2   berat  33.0  4432.0            3
# 1   cihan  25.0   348.0            2
# 0  ismail  17.0   975.0            1

# %%
print(dataframe1.loc[:,:"age"])
# Out:
#      name   age
# 0  ismail  17.0
# 1   cihan  25.0
# 2   berat  33.0
# 3   yasin  41.0
# 4  tayfun   NaN

# %%
print(dataframe1.iloc[:,[3]])
# Out:
#    yeni_future
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5

# %%
filtre1 = dataframe1.age>25                           
dataframe1["bool"]= filtre1
print(dataframe1.loc[:,["age","bool"]])
# Out:
#     age   bool
# 0  17.0  False
# 1  25.0  False
# 2  33.0   True
# 3  41.0   True
# 4   NaN  False

# %%
type(filtre1)
# Out:
# pandas.core.series.Series

# %%
filtrelenmis_data= dataframe1[filtre1] 
print(filtrelenmis_data)
# Out:
#     name   age    note  yeni_future  bool
# 2  berat  33.0  4432.0            3  True
# 3  yasin  41.0   254.0            4  True

# %%
filtre2 = dataframe1.note>150
filtrelenmis_data2 = dataframe1[filtre2&filtre1] 
print(filtrelenmis_data2)
# Out:
#     name   age    note  yeni_future  bool
# 2  berat  33.0  4432.0            3  True
# 3  yasin  41.0   254.0            4  True

# %%
dataframe1[dataframe1.age>35]
# Out:
#     name   age   note  yeni_future  bool
# 3  yasin  41.0  254.0            4  True

# %%
import numpy as np
ortalama = dataframe1.note.mean()
print(ortalama)
ortlama_np= np.mean(dataframe1.note) 
print(ortlama_np)
# Out:
# 1502.25
# 1502.25

# %%
dataframe1.dropna(inplace=True) 
dataframe1
# Out:
#      name   age    note  yeni_future   bool
# 0  ismail  17.0   975.0            1  False
# 1   cihan  25.0   348.0            2  False
# 2   berat  33.0  4432.0            3   True
# 3   yasin  41.0   254.0            4   True

# %%
print(dataframe1.note.mean()) 
dataframe1["ortalama"]= ["ortalamanın altında" if dataframe1.note.mean()>each else "ortalamanın üstünde" for each in dataframe1.note]
dataframe1
# Out:
# 1502.25
#      name   age    note  yeni_future   bool             ortalama
# 0  ismail  17.0   975.0            1  False  ortalamanın altında
# 1   cihan  25.0   348.0            2  False  ortalamanın altında
# 2   berat  33.0  4432.0            3   True  ortalamanın üstünde
# 3   yasin  41.0   254.0            4   True  ortalamanın altında

# %%
dataframe1.columns = [each.upper() for each in dataframe1.columns]
dataframe1.columns
# Out:
# Index(['NAME', 'AGE', 'NOTE', 'YENI_FUTURE', 'BOOL', 'ORTALAMA'], dtype='object')

# %%
dataframe1.columns = [ each.split(" ")[0]+"_"+each.split(" ")[1] if len(each.split(" "))>1 else each for each in dataframe1.columns]
dataframe1
# Out:
#      NAME   AGE    NOTE  YENI_FUTURE   BOOL             ORTALAMA
# 0  ismail  17.0   975.0            1  False  ortalamanın altında
# 1   cihan  25.0   348.0            2  False  ortalamanın altında
# 2   berat  33.0  4432.0            3   True  ortalamanın üstünde
# 3   yasin  41.0   254.0            4   True  ortalamanın altında

# %%
data1 = dataframe1.head()     
data2 = dataframe1.tail()
data_concat = pd.concat([data1,data2],axis=0)
data_concat
# Out:
#      NAME   AGE    NOTE  YENI_FUTURE   BOOL             ORTALAMA
# 0  ismail  17.0   975.0            1  False  ortalamanın altında
# 1   cihan  25.0   348.0            2  False  ortalamanın altında
# 2   berat  33.0  4432.0            3   True  ortalamanın üstünde
# 3   yasin  41.0   254.0            4   True  ortalamanın altında
# 0  ismail  17.0   975.0            1  False  ortalamanın altında
# 1   cihan  25.0   348.0            2  False  ortalamanın altında
# 2   berat  33.0  4432.0            3   True  ortalamanın üstünde
# 3   yasin  41.0   254.0            4   True  ortalamanın altında

# %%
data_contact2 = pd.concat([data1,data2],axis=1) 
data_contact2
# Out:
#      NAME   AGE    NOTE  YENI_FUTURE   BOOL             ORTALAMA    NAME  \
# 0  ismail  17.0   975.0            1  False  ortalamanın altında  ismail
# 1   cihan  25.0   348.0            2  False  ortalamanın altında   cihan
# 2   berat  33.0  4432.0            3   True  ortalamanın üstünde   berat
# 3   yasin  41.0   254.0            4   True  ortalamanın altında   yasin
#
#     AGE    NOTE  YENI_FUTURE   BOOL             ORTALAMA
# 0  17.0   975.0            1  False  ortalamanın altında
# 1  25.0   348.0            2  False  ortalamanın altında
# 2  33.0  4432.0            3   True  ortalamanın üstünde
# 3  41.0   254.0            4   True  ortalamanın altında

# %%
dataframe1["buyuk_yas"] = [each*2 for each in dataframe1.AGE]
dataframe1
# Out:
#      NAME   AGE    NOTE  YENI_FUTURE   BOOL             ORTALAMA  buyuk_yas
# 0  ismail  17.0   975.0            1  False  ortalamanın altında       34.0
# 1   cihan  25.0   348.0            2  False  ortalamanın altında       50.0
# 2   berat  33.0  4432.0            3   True  ortalamanın üstünde       66.0
# 3   yasin  41.0   254.0            4   True  ortalamanın altında       82.0

# %%
def mlt(yas):
    return yas*2
dataframe1["apply_metodu"] = dataframe1.AGE.apply(mlt)
dataframe1
# Out:
#      NAME   AGE    NOTE  YENI_FUTURE   BOOL             ORTALAMA  buyuk_yas  \
# 0  ismail  17.0   975.0            1  False  ortalamanın altında       34.0
# 1   cihan  25.0   348.0            2  False  ortalamanın altında       50.0
# 2   berat  33.0  4432.0            3   True  ortalamanın üstünde       66.0
# 3   yasin  41.0   254.0            4   True  ortalamanın altında       82.0
#
#    apply_metodu
# 0          34.0
# 1          50.0
# 2          66.0
# 3          82.0
